# %% [markdown]
# <a href="https://colab.research.google.com/github/UadrianSP/am-turma5/blob/main/TratamentoAD_aula0901.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pipeline de Analise de Dados [Census]

# %% [markdown]
# ## Importação de Bibliotecas
#
# *   Pandas
# *   Numpy
# *   MatPlotLib
# *   SeaBorn

# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Carregamento dos Dados da Base

# %%
base_census = pd.read_csv('/content/drive/MyDrive/am-t6/census.csv')

# %%
base_census
# Out:
#        age          workclass  final-weight    education  education-num  \
# 0       39          State-gov         77516    Bachelors             13
# 1       50   Self-emp-not-inc         83311    Bachelors             13
# 2       38            Private        215646      HS-grad              9
# 3       53            Private        234721         11th              7
# 4       28            Private        338409    Bachelors             13
# ...    ...                ...           ...          ...            ...
# 32556   27            Private        257302   Assoc-acdm             12
# 32557   40            Private        154374      HS-grad              9
# 32558   58            Private        151910      HS-grad              9
# 32559   22            Private        201490      HS-grad              9
# 32560   52       Self-emp-inc        287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# ...

# %%
base_census.describe()
# Out:
#                 age  final-weight  education-num  capital-gain  capital-loos  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hour-per-week
# count   32561.000000
# mean       40.437456
# std        12.347429
# min         1.000000
# 25%        40.000000
# 50%        40.000000
# 75%        45.000000
# max        99.000000

# %% [markdown]
# ## Caracteristicas da Base
# - População amostral: 32.561
# - Minorias importantes: 28 e 90, vol. Ed.=9
# e 16,
# ht= 40 e 99
# - Media amostral: idade = 38.58, Ed = 10,
# Gain. 1077.65, Loss = 87.30, ht= 40.44
# - Desvio Padrão: [limites]: idade = 24.94, Ed. = 7.
# 51, Gain. = -6757.64 Loss= -315.66, ht= 28,9

# %% [markdown]
# # Pipeline de Divisão dos Dados [Eixos de Aprendizagem(Credit_Data)]

# %%
X_credit = base_credit.iloc[:, 1:4].values

# %%
X_credit
# Out:
# array([[6.61559251e+04, 5.90170151e+01, 8.10653213e+03],
#        [3.44151540e+04, 4.81171531e+01, 6.56474502e+03],
#        [5.73171701e+04, 6.31080495e+01, 8.02095330e+03],
#        ...,
#        [4.43114493e+04, 2.80171669e+01, 5.52278669e+03],
#        [4.37560566e+04, 6.39717958e+01, 1.62272260e+03],
#        [6.94365796e+04, 5.61526170e+01, 7.37883360e+03]])

# %%
type(X_credit)
# Out:
# numpy.ndarray

# %%
Y_credit = base_credit.iloc[:, 4].values

# %%
Y_credit
# Out:
# array([0, 0, 0, ..., 1, 0, 0])

# %%
type(Y_credit)
# Out:
# numpy.ndarray

# %%
X_credit.shape, Y_credit.shape
# Out:
# ((2000, 3), (2000,))

# %%
X_credit[:,0].min(), X_credit[:,0].max()
# Out:
# (np.float64(20014.4894700497), np.float64(69995.6855783239))

# %%
from sklearn.preprocessing import StandardScaler
scaler_credit = StandardScaler()
X_credit = scaler_credit.fit_transform(X_credit)

# %%
X_credit[:,0].min(), X_credit[:,0].max()
# Out:
# (np.float64(-1.7676158019964077), np.float64(1.7220222385319197))

# %%
X_credit
# Out:
# array([[ 1.45393393,  1.36539359,  1.20281942],
#        [-0.76217555,  0.54267291,  0.69642695],
#        [ 0.83682073,  1.67418453,  1.17471147],
#        ...,
#        [-0.07122592, -0.97447238,  0.35420081],
#        [-0.11000289,  1.73938004, -0.92675625],
#        [ 1.682986  ,  1.14918907,  0.96381038]])

# %% [markdown]
# ## Amostras de Testes

# %%
from sklearn.model_selection import train_test_split

# %%
X_credit_train, X_credit_test, Y_credit_train, Y_credit_test = train_test_split(X_credit, Y_credit, test_size=0.25, random_state=0)

# %% [markdown]
# ### Digestão de amostra do algoritmo de Naive Bayes

# %%
X_credit_train.shape, Y_credit_train.shape
# Out:
# ((1500, 3), (1500,))

# %% [markdown]
# ### Gabarito de acurácia do algoritmo de Naive Bayes

# %%
X_credit_test.shape, Y_credit_test.shape
# Out:
# ((500, 3), (500,))

# %% [markdown]
# ## Convertendo em Pickle

# %%
import pickle

# %%
with open('/content/drive/MyDrive/am-t6/credit.pkl', mode='wb') as f:
  pickle.dump([X_credit_train, Y_credit_train, X_credit_test, Y_credit_test], f)
